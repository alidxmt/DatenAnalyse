# %% [markdown]
# # Lebensmittelzusammensetzungs Datenbank
#
# Dieses Notebook untersucht eine Lebensmittelzusammensetzungsdatenbank, die Nährwertinformationen für verschiedene Lebensmittel enthält, einschließlich Mengen an Vitaminen und Mineralstoffen sowie Prozentsätzen der Makronährstoffe. Wir werden den Datensatz laden, seine Struktur untersuchen, grundlegende Bereinigungen und zusammenfassende Statistiken durchführen und das DataFrame anzeigen.
#
# Geplante Schritte:
# - Datensatz laden (CSV/Excel)
# - Spalten, Datentypen und fehlende Werte prüfen
# - DataFrame anzeigen (head)
#
# Wir beginnen damit, die Datei zu lesen und das DataFrame anzuzeigen.

# %% [markdown]
# ---

# %% [markdown]
# # 🐍 Reverse Practice mit Python
#
# KI kann heutzutage meist sauberen und effizienten Code vorschlagen.
# Um trotzdem besser zu lernen, machen wir **Reverse Practice**:
#
# - 🔹 Start mit funktionierendem Code und **schreibe Kommentare**, die erklären, was jeder Teil macht.
# - 🔹 Kommentare sind in **natürlicher Sprache** und können später genutzt werden, um Code wieder zu generieren.
# - 🔹 So lernen wir, welche **Funktionen und Möglichkeiten** Python bietet.
#
# 💡 Insgesamt stärkt diese Übung unser **konzeptionelles Verständnis** und unsere **Programmierfähigkeiten**.

# %% [markdown]
# ---

# %% [markdown]
# Bitte schreibe **Kommentare** zum folgenden Code im Code-Block,
# wo `# ---` steht.
# Die Kommentare sollten in **klarer, natürlicher Sprache** erklären,
# was jeder Abschnitt des Codes macht.
#
# Verwende die geringstmögliche Anzahl an Wörtern.
# LLMs (KI) sind die besten Werkzeuge, um Text kürzer zu schreiben und Redundanzen zu vermeiden.

# %%
# Here we get data from file which is in same folder of notebook in local computer
# Please write behind line where the sign is what does the next block of code
# ---
import pandas as pd
from IPython.display import display

file = "food.csv"

try:
    # ---
    df = pd.read_csv(file)
except Exception as e:
    print(f"Error reading {file}: {e}")

# %%
#---- please change number, here is 4 to other numbers and run again and see the result
df.head(4)

# %%
#--- comment here, we used it yesterday, what .info does here
df.info()

# %%
# ----------- please comment here what does describe does. it is one of most helpful functions in pandas
df.describe(include='number')

# %%
# ---- the name .columns is self-evident
df.columns
