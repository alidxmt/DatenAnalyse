# %% [markdown]
# # Data Visualization

# %% [markdown]
# <hr style="height:6px; border:none; color:rgb(125,25,25); background-color:rgb(125,25,25);" />

# %%
# import libraries
import pandas as pd
import matplotlib as mtl

# %% [markdown]
# ## Dataset
# Let's use various descriptive statistics and data visualization techniques on the following dataframe
# Titanic Passengers and Crew Complete List

# %%
# read csv
df = pd.read_csv("titanic.csv")
df.head(2)
# Out:
#                         name gender   age class embarked        country  \
# 0        Abbing, Mr. Anthony   male  42.0   3rd        S  United States
# 1  Abbott, Mr. Eugene Joseph   male  13.0   3rd        S  United States
#
#    ticketno   fare  sibsp  parch survived
# 0    5547.0   7.11    0.0    0.0       no
# 1    2673.0  20.05    0.0    2.0       no

# %% [markdown]
# ## Estimate of Location

# %% [markdown]
# ### Mean
# The sum of all values divided by the number of values |  Average

# %%
# code here

# %% [markdown]
# #### Trimmed mean
# The average of all values after dropping a fixed number of extreme values | Truncated mean

# %%
# code here

# %% [markdown]
# #### Weighted mean
# The sum of all values times a weight divided by the sum of the weights | Weighted Average

# %%
# code here

# %% [markdown]
# ---

# %% [markdown]
# ### Median

# %%
# code here

# %% [markdown]
# #### Weighted Median

# %%
# code here

# %% [markdown]
# <hr style="height:6px; border:none; color:rgb(125,25,25); background-color:rgb(125,25,25);" />

# %% [markdown]
# ## Estimates of Variability

# %% [markdown]
# ### Deviations
# The difference between the observed values and the estimate of location | errors, residuals

# %%
# code here

# %% [markdown]
# ### Variance
# The sum of squared deviations from the mean divided by n-1 where n is the number of data values | mean_squared-error | mean-squared-error

# %%
# code here

# %% [markdown]
# ### Standard Deviation
# The square root of the variance | 2-norm, Euclidian norm

# %%
# code here

# %% [markdown]
# ### Mean absolute deviation
# The mean of the absolute value of the deviations from the mean | 1-norm, Manhattan norm

# %%
# code here

# %% [markdown]
# ### Median absolute deviation from the median
# the median of the absolute value of the deviations from the median

# %%
# code here

# %% [markdown]
# ### Range
# The difference between the largest and the smallest value in a data set

# %%
# code here

# %% [markdown]
# ### Order Statistics
# Metrics based on the data values sorted from smallest to biggest | Ranks

# %%
# code here

# %% [markdown]
# ### Percentale
# The value such that P percent of the values take on this value or less and (100-p) percent take on this value or more | Quantile

# %%
# code here

# %% [markdown]
# ### Interquartile range
# The difference between the 75th percentile and the 25th percentile | IQR

# %%
# code here

# %% [markdown]
# ### Bar Chart
# Frequency Counting of Categorical data

# %%
#code here

# %% [markdown]
# ### Frequency counting and Histogram
# Frequency counting of Numerical data through intervals

# %%
#code here

# %% [markdown]
# ### Quantile and BoxPlot

# %%
# code here
