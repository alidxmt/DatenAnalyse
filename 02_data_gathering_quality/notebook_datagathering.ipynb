# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\flask\lib\site-packages (2.32.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\flask\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\flask\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\flask\lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\envs\flask\lib\site-packages (from requests) (3.4.4)

# %%
import requests

url = "https://jsonplaceholder.typicode.com/posts"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print("First post:")
    print(data[0])
else:
    print("Error:", response.status_code)
# Out:
# First post:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
import requests

url = "https://randomuser.me/api/"

response = requests.get(url)
data = response.json()

print(data["results"][0]["name"])
# Out:
# {'title': 'Mr', 'first': 'Gilberto', 'last': 'Camacho'}
